# %% [markdown]
# # Indian movies

# %% [markdown]
# The goal of this project is to find the most rating with the highest number of votes of Indian movies, Also, most type of movies from 2019 to 2021, to recommend you buy the ticket and enjoy your time watching.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# To start achieving this goal, we used a bar chart model .This figure depicts the model top five Indian movies which have the highest rating, and votes  from the year 2019 to 2021
